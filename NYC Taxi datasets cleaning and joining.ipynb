# %% [markdown]
# Data set from DataPlayground Maven Analytics

# %% [markdown]
# What is the average number of trips per week?
#
# What is the average distance traveled per trip?
#
# Which days of the week and times of the day will be busiest?
#
# What are the most popular pick-up and drop-off locations?

# %%
import pandas as pd

# %%
d=pd.read_csv('data_dictionary.csv',encoding='latin1')

# %% [markdown]
# FIELD DETAILS

# %% [markdown]
# VendorID-A code indicating the LPEP provider that provided the record (1= Creative Mobile Technologies, LLC; 2= Verifone Inc.)
#
# lpep_pickup_datetime-The date and time when the meter was engaged
#
# lpep_dropoff_datetime-The date and time when the meter was disengaged
#
# store_and_fwd_flag-This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka “store and forward,” because the vehicle did not have a connection to the server (Y= store and forward trip; N= not a store and forward trip)
#
# RatecodeID-The final rate code in effect at the end of the trip (1= Standard rate; 2= JFK; 3= Newark; 4= Nassau or Westchester; 5= Negotiated fare; 6= Group ride)
#
# PULocationID-TLC Taxi Zone in which the taximeter was engaged
#
# DOLocationID-TLC Taxi Zone in which the taximeter was disengaged
#
# passenger_count-The number of passengers in the vehicle (this is a driver entered value)
#
# trip_distance-The elapsed trip distance in miles reported by the taximeter
#
# fare_amount-The time-and-distance fare calculated by the meter
#
# extra-Miscellaneous extras and surcharges (this only includes the $0.50 and $1 rush hour and overnight charges)
#
# mta_tax-$0.50 MTA tax that is automatically triggered based on the metered rate in use
#
# tip_amount-Tip amount (automatically populated for credit card tips - cash tips are not included)
#
# tolls_amount-Total amount of all tolls paid in trip
#
# improvement_surcharge-$0.30 improvement surcharge assessed on hailed trips at the flag drop
#
# total_amount-The total amount charged to passengers (does not include cash tips)
#
# payment_type-A numeric code signifying how the passenger paid for the trip (1= Credit card; 2= Cash; 3= No charge; 4= Dispute; 5= Unknown; 6= Voided trip)
#
# trip_type-A code indicating whether the trip was a street-hail or a dispatch that is automatically assigned based on the metered rate in use but can be altered by the driver (1= Street-hail; 2= Dispatch)
#
# congestion_surcharge-Congestion surcharge for trips that start, end or pass through the congestion zone in Manhattan, south of 96th street ($2.50 for non-shared trips in Yellow Taxis; $2.75 for non-shared trips in Green Taxis)

# %% [markdown]
# 2017 taxi data

# %%
df1=pd.read_csv('2017_taxi_trips.csv')

# %%
df1.head()
# Out:
#    VendorID     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 0         1  2017-01-01 09:00:01.000  2017-01-01 09:03:56.000
# 1         1  2017-01-01 18:57:55.000  2017-01-01 19:01:16.000
# 2         2  2017-01-02 06:55:47.000  2017-01-02 06:58:54.000
# 3         2  2017-01-02 14:34:17.000  2017-01-02 14:39:29.000
# 4         1  2017-01-03 06:12:30.000  2017-01-03 06:15:56.000
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N           1            74            41                1
# 1                  N           1            42            41                1
# 2                  N           1            42            41                1
# 3                  N           1            74            41                1
# 4                  N           1            42            41                1
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11740667 entries, 0 to 11740666
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             int64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        int64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           int64
#  17  trip_type              float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.6+ GB

# %%
df1['lpep_pickup_datetime']=pd.to_datetime(df1['lpep_pickup_datetime'])

# %%
df1['lpep_dropoff_datetime']=pd.to_datetime(df1['lpep_pickup_datetime'])

# %%
df1['trip_type'].fillna(0,axis=0,inplace=True)

# %%
df1['trip_type']=df1['trip_type'].astype('int')

# %%
df1['trip_type'].value_counts()
# Out:
# 1    11524542
# 2      216098
# 0          27
# Name: trip_type, dtype: int64

# %%
df1['trip_type']=df1['trip_type'].astype('str')

# %%
df1['trip_type']=df1['trip_type'].str.replace('0',df1['trip_type'].value_counts().idxmax())

# %%
df1['trip_type'].value_counts()
# Out:
# 1    11524569
# 2      216098
# Name: trip_type, dtype: int64

# %%
df1.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  1.174067e+07  1.174067e+07  1.174067e+07  1.174067e+07
# mean   1.804665e+00  1.077787e+00  1.118996e+02  1.290602e+02
# std    3.964585e-01  5.625980e-01  7.588120e+01  7.723227e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  1.000000e+00  4.900000e+01  6.100000e+01
# 50%    2.000000e+00  1.000000e+00  8.200000e+01  1.290000e+02
# 75%    2.000000e+00  1.000000e+00  1.660000e+02  1.930000e+02
# max    2.000000e+00  9.900000e+01  2.650000e+02  2.650000e+02
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     1.174067e+07   1.174067e+07  1.174067e+07  1.174067e+07
# mean      1.364449e+00   2.684420e+00  1.179504e+01  3.527367e-01
# std       1.039248e+00   2.828545e+00  9.875311e+00  3.891518e-01
# min       0.000000e+00   0.000000e+00 -4.800000e+02 -4.500000e+00
# 25%       1.000000e+00   1.000000e+00  6.000000e+00  0.000000e+00
# ...

# %%
df1.duplicated().sum()
# Out:
# 56

# %%
df1[df1.duplicated()==True]
# Out:
#          VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 322310          2  2017-01-04 20:01:15   2017-01-04 20:01:15
# 1207863         2  2017-07-24 10:51:08   2017-07-24 10:51:08
# 1229795         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229796         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229797         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229798         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229799         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229800         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229801         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229802         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229803         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229804         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229805         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# 1229806         2  2017-06-29 17:01:37   2017-06-29 17:01:37
# ...

# %% [markdown]
# 2018 taxi data

# %%
df2=pd.read_csv('2018_taxi_trips.csv')

# %%
df2.head()
# Out:
#    VendorID     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 0         2  2018-04-29 13:58:05.000  2018-04-29 14:02:49.000
# 1         2  2018-04-29 17:48:02.000  2018-04-29 17:52:55.000
# 2         2  2018-04-29 18:25:03.000  2018-04-29 18:30:59.000
# 3         2  2018-04-29 19:14:14.000  2018-04-29 19:20:35.000
# 4         2  2018-04-30 06:30:16.000  2018-04-30 06:34:57.000
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N           1            74            75                1
# 1                  N           1            74            75                1
# 2                  N           1            74            75                1
# 3                  N           1            74            75                1
# 4                  N           1            74            75                1
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807303 entries, 0 to 8807302
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             int64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        int64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           int64
#  17  trip_type              float64
# dtypes: float64(9), int64(6), object(3)
# memory usage: 1.2+ GB

# %%
df2['lpep_pickup_datetime']=pd.to_datetime(df2['lpep_pickup_datetime'])
df2['lpep_dropoff_datetime']=pd.to_datetime(df2['lpep_pickup_datetime'])

# %%
df2.isnull().sum()
# Out:
# VendorID                  0
# lpep_pickup_datetime      0
# lpep_dropoff_datetime     0
# store_and_fwd_flag        0
# RatecodeID                0
# PULocationID              0
# DOLocationID              0
# passenger_count           0
# trip_distance             0
# fare_amount               0
# extra                     0
# mta_tax                   0
# tip_amount                0
# tolls_amount              0
# improvement_surcharge     0
# total_amount              0
# payment_type              0
# trip_type                63
# dtype: int64

# %%
df2['trip_type'].fillna(0,axis=0,inplace=True)

# %%
df2['trip_type']=df2['trip_type'].astype('int')

# %%
df2['trip_type'].value_counts()
# Out:
# 1    8562018
# 2     245222
# 0         63
# Name: trip_type, dtype: int64

# %%
df2['trip_type']=df2['trip_type'].astype('str')

# %%
df2['trip_type']=df2['trip_type'].str.replace('0',df1['trip_type'].value_counts().idxmax())

# %%
df2['trip_type'].value_counts()
# Out:
# 1    8562081
# 2     245222
# Name: trip_type, dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 77

# %%
df2[df2.duplicated()==True].sort_values(by=['lpep_pickup_datetime','lpep_dropoff_datetime'])
# Out:
#          VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 3306875         1  2018-01-09 15:15:01   2018-01-09 15:15:01
# 4112333         2  2018-01-21 14:46:03   2018-01-21 14:46:03
# 3326457         2  2018-01-23 13:40:40   2018-01-23 13:40:40
# 3326458         2  2018-01-23 13:40:40   2018-01-23 13:40:40
# 3326459         2  2018-01-23 13:40:40   2018-01-23 13:40:40
# ...           ...                  ...                   ...
# 4206719         2  2018-08-18 13:34:45   2018-08-18 13:34:45
# 7540438         2  2018-09-22 06:47:51   2018-09-22 06:47:51
# 7829722         2  2018-09-27 17:08:09   2018-09-27 17:08:09
# 7829733         2  2018-09-28 18:58:46   2018-09-28 18:58:46
# 7629498         2  2018-10-05 23:57:49   2018-10-05 23:57:49
#
#         store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 3306875                  N           1           145           145
# 4112333                  N           1             7           193
# ...

# %%
df2.describe()
# Out:
#            VendorID    RatecodeID  PULocationID  DOLocationID  \
# count  8.807303e+06  8.807303e+06  8.807303e+06  8.807303e+06
# mean   1.838599e+00  1.114501e+00  1.107596e+02  1.288048e+02
# std    3.679003e-01  7.109747e-01  7.406614e+01  7.676787e+01
# min    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  1.000000e+00  4.900000e+01  6.200000e+01
# 50%    2.000000e+00  1.000000e+00  8.200000e+01  1.290000e+02
# 75%    2.000000e+00  1.000000e+00  1.660000e+02  1.930000e+02
# max    2.000000e+00  9.900000e+01  2.650000e+02  2.650000e+02
#
#        passenger_count  trip_distance   fare_amount         extra  \
# count     8.807303e+06   8.807303e+06  8.807303e+06  8.807303e+06
# mean      1.350579e+00   3.184364e+00  1.342791e+01  3.268840e-01
# std       1.030374e+00   4.528788e+00  1.266496e+01  3.958528e-01
# min       0.000000e+00   0.000000e+00 -5.000000e+02 -2.542000e+01
# 25%       1.000000e+00   1.060000e+00  6.500000e+00  0.000000e+00
# ...

# %% [markdown]
# 2019 taxi data

# %%
df3=pd.read_csv('2019_taxi_trips.csv')
# Out:
# /Users/sumakari/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3.head()
# Out:
#    VendorID     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 0       2.0  2019-04-17 08:58:00.000  2019-04-17 09:04:30.000
# 1       2.0  2019-04-17 12:36:53.000  2019-04-17 12:43:34.000
# 2       2.0  2019-04-17 12:17:55.000  2019-04-17 12:25:18.000
# 3       2.0  2019-04-17 15:49:50.000  2019-04-17 15:58:01.000
# 4       2.0  2019-04-18 13:22:23.000  2019-04-18 13:29:37.000
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N         1.0            41            42              1.0
# 1                  N         1.0            41            42              1.0
# 2                  N         1.0            41            42              1.0
# 3                  N         1.0            41            42              1.0
# 4                  N         1.0            41            42              1.0
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6044050 entries, 0 to 6044049
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             float64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           float64
#  17  trip_type              float64
#  18  congestion_surcharge   float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 876.1+ MB

# %%
df3['lpep_pickup_datetime']=pd.to_datetime(df3['lpep_pickup_datetime'])
df3['lpep_dropoff_datetime']=pd.to_datetime(df3['lpep_pickup_datetime'])

# %%
df3.isnull().sum()
# Out:
# VendorID                 414107
# lpep_pickup_datetime          0
# lpep_dropoff_datetime         0
# store_and_fwd_flag       414107
# RatecodeID               414107
# PULocationID                  0
# DOLocationID                  0
# passenger_count          414107
# trip_distance                 0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         2
# total_amount                  0
# payment_type             414107
# trip_type                414466
# congestion_surcharge     960489
# dtype: int64

# %%
df3.shape
# Out:
# (6044050, 19)

# %%
df3['VendorID'].fillna(0,inplace=True)

# %%
df3['VendorID']=df3['VendorID'].astype('int').astype('str')

# %%
df3['VendorID']=df3['VendorID'].str.replace('0',df3['VendorID'].value_counts().idxmax())

# %%
df3['store_and_fwd_flag'].fillna(df3['store_and_fwd_flag'].value_counts().idxmax(),inplace=True)

# %%
df3['RatecodeID'].fillna(0,inplace=True)
df3['RatecodeID']=df3['RatecodeID'].astype('int').astype('str')
df3['RatecodeID']=df3['RatecodeID'].str.replace('0',df3['RatecodeID'].value_counts().idxmax())

# %%
df3['passenger_count'].fillna(df3['passenger_count'].mean(),inplace=True)

# %%
df3['payment_type'].fillna(0,inplace=True)
df3['payment_type']=df3['payment_type'].astype('int').astype('str')
df3['payment_type']=df3['payment_type'].str.replace('0',df3['payment_type'].value_counts().idxmax())

# %%
df3['trip_type'].fillna(0,inplace=True)
df3['trip_type']=df3['trip_type'].astype('int').astype('str')
df3['trip_type']=df3['trip_type'].str.replace('0',df3['trip_type'].value_counts().idxmax())

# %%
df3['congestion_surcharge'].fillna(df3['congestion_surcharge'].mean(),inplace=True)

# %%
df3.isnull().sum()
# Out:
# VendorID                 0
# lpep_pickup_datetime     0
# lpep_dropoff_datetime    0
# store_and_fwd_flag       0
# RatecodeID               0
# PULocationID             0
# DOLocationID             0
# passenger_count          0
# trip_distance            0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    2
# total_amount             0
# payment_type             0
# trip_type                0
# congestion_surcharge     0
# dtype: int64

# %% [markdown]
# df1 and df2 have no congestion charge values

# %%
df3.duplicated().sum()
# Out:
# 89

# %%
df3[df3.duplicated()==True]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 209813         2  2019-04-26 07:53:06   2019-04-26 07:53:06
# 1540211        2  2019-11-12 13:17:00   2019-11-12 13:17:00
# 1540226        2  2019-11-14 14:12:00   2019-11-14 14:12:00
# 1540334        2  2019-12-27 12:05:00   2019-12-27 12:05:00
# 1879177        2  2019-09-07 19:20:45   2019-09-07 19:20:45
# ...          ...                  ...                   ...
# 5557574        2  2019-02-19 15:49:00   2019-02-19 15:49:00
# 5557584        2  2019-02-19 16:10:00   2019-02-19 16:10:00
# 5557607        2  2019-02-20 10:13:00   2019-02-20 10:13:00
# 5557624        2  2019-02-20 12:01:00   2019-02-20 12:01:00
# 5557639        2  2019-02-20 14:28:00   2019-02-20 14:28:00
#
#         store_and_fwd_flag RatecodeID  PULocationID  DOLocationID  \
# 209813                   N          1           205            85
# 1540211                  N          5           264           264
# ...

# %%
df3.describe()
# Out:
#        PULocationID  DOLocationID  passenger_count  trip_distance  \
# count  6.044050e+06  6.044050e+06     6.044050e+06   6.044050e+06
# mean   1.084717e+02  1.292570e+02     1.310093e+00   3.303150e+00
# std    7.173679e+01  7.650462e+01     9.369814e-01   3.435201e+01
# min    1.000000e+00  1.000000e+00     0.000000e+00  -2.032908e+04
# 25%    5.200000e+01  6.500000e+01     1.000000e+00   1.060000e+00
# 50%    8.200000e+01  1.290000e+02     1.000000e+00   1.950000e+00
# 75%    1.660000e+02  1.930000e+02     1.000000e+00   3.920000e+00
# max    2.650000e+02  2.650000e+02     9.000000e+00   7.784376e+04
#
#         fare_amount         extra       mta_tax    tip_amount  tolls_amount  \
# count  6.044050e+06  6.044050e+06  6.044050e+06  6.044050e+06  6.044050e+06
# mean   1.442893e+01  5.376410e-01  4.825997e-01  9.843494e-01  2.530078e-01
# std    1.316129e+01  8.476131e-01  1.000936e-01  2.017130e+00  1.365045e+00
# ...

# %% [markdown]
# 2020 taxi data

# %%
df4=pd.read_csv('2020_taxi_trips.csv')
# Out:
# /Users/sumakari/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df4.head()
# Out:
#    VendorID     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 0       2.0  2020-01-01 06:47:28.000  2020-01-01 06:52:54.000
# 1       2.0  2020-01-01 13:25:34.000  2020-01-01 13:30:43.000
# 2       2.0  2020-01-01 14:20:35.000  2020-01-01 14:26:25.000
# 3       2.0  2020-01-02 06:56:47.000  2020-01-02 07:03:03.000
# 4       2.0  2020-01-02 09:34:46.000  2020-01-02 09:41:02.000
#
#   store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# 0                  N         1.0            74            75              1.0
# 1                  N         1.0            74            75              1.0
# 2                  N         1.0            74            75              1.0
# 3                  N         1.0            74            75              1.0
# 4                  N         1.0            74            75              1.0
#
#    trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1734051 entries, 0 to 1734050
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               float64
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             float64
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           float64
#  17  trip_type              float64
#  18  congestion_surcharge   float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 251.4+ MB

# %%
df4.isnull().sum()
# Out:
# VendorID                 528092
# lpep_pickup_datetime          0
# lpep_dropoff_datetime         0
# store_and_fwd_flag       528092
# RatecodeID               528092
# PULocationID                  0
# DOLocationID                  0
# passenger_count          528092
# trip_distance                 0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# payment_type             528092
# trip_type                528097
# congestion_surcharge     528092
# dtype: int64

# %%
df4['VendorID'].fillna(0,inplace=True)
df4['VendorID']=df4['VendorID'].astype('int').astype('str')
df4['VendorID']=df4['VendorID'].str.replace('0',df4['VendorID'].value_counts().idxmax())

# %%
df4['store_and_fwd_flag'].fillna(df4['store_and_fwd_flag'].value_counts().idxmax(),inplace=True)

# %%
df4['RatecodeID'].fillna(0,inplace=True)
df4['RatecodeID']=df4['RatecodeID'].astype('int').astype('str')
df4['RatecodeID']=df4['RatecodeID'].str.replace('0',df4['RatecodeID'].value_counts().idxmax())

# %%
df4['passenger_count'].fillna(df4['passenger_count'].mean(),inplace=True)

# %%
df4['payment_type'].fillna(0,inplace=True)
df4['payment_type']=df4['payment_type'].astype('int').astype('str')
df4['payment_type']=df4['payment_type'].str.replace('0',df4['payment_type'].value_counts().idxmax())

# %%
df4['trip_type'].fillna(0,inplace=True)
df4['trip_type']=df4['trip_type'].astype('int').astype('str')
df4['trip_type']=df4['trip_type'].str.replace('0',df4['trip_type'].value_counts().idxmax())

# %%
df4['congestion_surcharge'].fillna(df4['congestion_surcharge'].mean(),inplace=True)

# %%
df4.duplicated().sum()
# Out:
# 138

# %%
df4[df4.duplicated()==True].sort_values(by=['PULocationID'])
# Out:
#        VendorID     lpep_pickup_datetime    lpep_dropoff_datetime  \
# 394517        2  2020-01-03 22:24:00.000  2020-01-03 22:34:00.000
# 347958        2  2020-01-02 17:28:00.000  2020-01-02 17:45:00.000
# 353357        2  2020-01-02 05:18:00.000  2020-01-02 05:24:00.000
# 386208        2  2020-01-04 12:55:00.000  2020-01-04 13:07:00.000
# 386210        2  2020-01-04 13:24:00.000  2020-01-04 13:36:00.000
# ...         ...                      ...                      ...
# 350761        2  2020-01-03 07:10:00.000  2020-01-03 07:10:00.000
# 381492        2  2020-01-04 12:46:00.000  2020-01-04 13:15:00.000
# 363966        2  2020-01-05 10:54:00.000  2020-01-05 10:54:00.000
# 350296        2  2020-01-02 16:06:00.000  2020-01-02 16:08:00.000
# 347571        2  2020-01-03 14:16:00.000  2020-01-03 14:16:00.000
#
#        store_and_fwd_flag RatecodeID  PULocationID  DOLocationID  \
# 394517                  N          1             3             3
# ...

# %%
df1=df1.append(df2)

# %%
df1['congestion_surcharge']=0

# %%
df1=df1.append(df3)

# %%
df1=df4.append(df1)

# %%
df1.shape
# Out:
# (28326071, 19)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28326071 entries, 0 to 6044049
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               object
#  1   lpep_pickup_datetime   object
#  2   lpep_dropoff_datetime  object
#  3   store_and_fwd_flag     object
#  4   RatecodeID             object
#  5   PULocationID           int64
#  6   DOLocationID           int64
#  7   passenger_count        float64
#  8   trip_distance          float64
#  9   fare_amount            float64
#  10  extra                  float64
#  11  mta_tax                float64
#  12  tip_amount             float64
#  13  tolls_amount           float64
#  14  improvement_surcharge  float64
#  15  total_amount           float64
#  16  payment_type           object
#  17  trip_type              object
#  18  congestion_surcharge   float64
# dtypes: float64(10), int64(2), object(7)
# memory usage: 4.2+ GB

# %%
df1.to_csv('NYC.csv')
